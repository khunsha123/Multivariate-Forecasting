# %% [markdown]
# **Approach used:** SARIMAX (Seasonal Autoregressive Integrated Moving Average with eXogeneous variables)
#
# **Reason:** The data provided is seasonal, and it is a time series data with multiple exogeneous variables influencing the result. Hence, the optimal statistical model that can be applied to this task is SARIMAX

# %% [markdown]
# **Main Modules Used:**
#
# statsmodel package in Python

# %% [markdown]
# ## Import Required Modules

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
import statsmodels.api as sm
from tqdm import tqdm

# %% [markdown]
# ## Read the Train Data

# %%
data = pd.read_csv('/content/Train.csv')
data.index = data.date_time
data = data.drop(['date_time'],axis=1)
data.head()
# Out:
#                     is_holiday  air_pollution_index  humidity  wind_speed  \
# date_time
# 2012-10-02 09:00:00        NaN                  121        89           2
# 2012-10-02 10:00:00        NaN                  178        67           3
# 2012-10-02 11:00:00        NaN                  113        66           3
# 2012-10-02 12:00:00        NaN                   20        66           3
# 2012-10-02 13:00:00        NaN                  281        65           3
#
#                      wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2012-10-02 09:00:00             329                    1          1
# 2012-10-02 10:00:00             330                    1          1
# 2012-10-02 11:00:00             329                    2          2
# 2012-10-02 12:00:00             329                    5          5
# 2012-10-02 13:00:00             329                    7          7
#
#                      temperature  rain_p_h  snow_p_h  clouds_all weather_type  \
# date_time
# 2012-10-02 09:00:00       288.28       0.0         0          40       Clouds
# 2012-10-02 10:00:00       289.36       0.0         0          75       Clouds
# 2012-10-02 11:00:00       289.58       0.0         0          90       Clouds
# 2012-10-02 12:00:00       290.13       0.0         0          90       Clouds
# 2012-10-02 13:00:00       291.14       0.0         0          75       Clouds
#
#                     weather_description  traffic_volume
# date_time
# 2012-10-02 09:00:00    scattered clouds          5545.0
# 2012-10-02 10:00:00       broken clouds          4516.0
# 2012-10-02 11:00:00     overcast clouds          4767.0
# 2012-10-02 12:00:00     overcast clouds          5026.0
# 2012-10-02 13:00:00       broken clouds          4918.0

# %% [markdown]
# ## Data Preprocessing
# For handling categorical variables is_holiday, weather_type, weather_description, we perform one-hot encoding

# %%
def pre_process(data):
    data['holiday'] = 0
    for i in tqdm(range(len(data))):
        if(data.iloc[i]['is_holiday'] != "None"):
            data.iloc[i]['holiday'] = 1
    weather_type = pd.get_dummies(data['weather_type'],prefix="weather_type")
    weather_desc = pd.get_dummies(data['weather_description'],prefix="weather_desc")
    data = data.drop(['weather_type','weather_description','is_holiday'],axis=1)
    data = pd.concat([data,weather_type,weather_desc],axis=1)
    data.head()
    return(data)

# %%
data = pre_process(data)
# Out:
#   0%|          | 0/13313 [00:00<?, ?it/s]<ipython-input-6-5fe0e72183f9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.iloc[i]['holiday'] = 1
# 100%|██████████| 13313/13313 [00:02<00:00, 4508.42it/s]

# %% [markdown]
# ## Train Data Assignment

# %%
train = data

# %% [markdown]
# ## Specify endogenous and exogenous variables in the data

# %%
# Variables
exog_data = train.drop(['traffic_volume'],axis=1)
exog = sm.add_constant(exog_data)
endog = train[[u'traffic_volume']]

print(endog)
print(exog)
# nobs = endog.shape[0]
# Out:
#                      traffic_volume
# date_time
# 2012-10-02 09:00:00          5545.0
# 2012-10-02 10:00:00          4516.0
# 2012-10-02 11:00:00          4767.0
# 2012-10-02 12:00:00          5026.0
# 2012-10-02 13:00:00          4918.0
# ...                             ...
# 2014-03-31 00:00:00           582.0
# 2014-03-31 01:00:00           365.0
# 2014-03-31 02:00:00           359.0
# 2014-03-31 03:00:00           364.0
# 2014-03-31 04:00:00             NaN
#
# [13313 rows x 1 columns]
#                      const  air_pollution_index  humidity  wind_speed  \
# date_time
# 2012-10-02 09:00:00    1.0                  121        89           2
# 2012-10-02 10:00:00    1.0                  178        67           3
# 2012-10-02 11:00:00    1.0                  113        66           3
# 2012-10-02 12:00:00    1.0                   20        66           3
# 2012-10-02 13:00:00    1.0                  281        65           3
# ...                    ...                  ...       ...         ...
# 2014-03-31 00:00:00    1.0                  195        37           6
# 2014-03-31 01:00:00    1.0                  297        45           3
# 2014-03-31 02:00:00    1.0                  285        45           1
# 2014-03-31 03:00:00    1.0                  135        55           0
# 2014-03-31 04:00:00    1.0                  222        59           0
#
#                      wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2012-10-02 09:00:00             329                    1          1
# 2012-10-02 10:00:00             330                    1          1
# 2012-10-02 11:00:00             329                    2          2
# 2012-10-02 12:00:00             329                    5          5
# 2012-10-02 13:00:00             329                    7          7
# ...                             ...                  ...        ...
# 2014-03-31 00:00:00             320                    9          9
# 2014-03-31 01:00:00             300                    5          5
# 2014-03-31 02:00:00             300                    1          1
# 2014-03-31 03:00:00               0                    5          5
# 2014-03-31 04:00:00               0                    4          4
#
#                      temperature  rain_p_h  snow_p_h  ...  \
# date_time                                             ...
# 2012-10-02 09:00:00       288.28       0.0         0  ...
# 2012-10-02 10:00:00       289.36       0.0         0  ...
# 2012-10-02 11:00:00       289.58       0.0         0  ...
# 2012-10-02 12:00:00       290.13       0.0         0  ...
# 2012-10-02 13:00:00       291.14       0.0         0  ...
# ...                          ...       ...       ...  ...
# 2014-03-31 00:00:00       280.90       0.0         0  ...
# 2014-03-31 01:00:00       280.93       0.0         0  ...
# 2014-03-31 02:00:00       280.73       0.0         0  ...
# 2014-03-31 03:00:00       280.81       0.0         0  ...
# 2014-03-31 04:00:00       280.83       0.0         0  ...
#
#                      weather_desc_shower snow  weather_desc_sky is clear  \
# date_time
# 2012-10-02 09:00:00                     False                      False
# 2012-10-02 10:00:00                     False                      False
# 2012-10-02 11:00:00                     False                      False
# 2012-10-02 12:00:00                     False                      False
# 2012-10-02 13:00:00                     False                      False
# ...                                       ...                        ...
# 2014-03-31 00:00:00                     False                      False
# 2014-03-31 01:00:00                     False                      False
# 2014-03-31 02:00:00                     False                      False
# 2014-03-31 03:00:00                     False                      False
# 2014-03-31 04:00:00                     False                      False
#
#                      weather_desc_snow  weather_desc_thunderstorm  \
# date_time
# 2012-10-02 09:00:00              False                      False
# 2012-10-02 10:00:00              False                      False
# 2012-10-02 11:00:00              False                      False
# 2012-10-02 12:00:00              False                      False
# 2012-10-02 13:00:00              False                      False
# ...                                ...                        ...
# 2014-03-31 00:00:00              False                      False
# 2014-03-31 01:00:00              False                      False
# 2014-03-31 02:00:00              False                      False
# 2014-03-31 03:00:00              False                      False
# 2014-03-31 04:00:00              False                      False
#
#                      weather_desc_thunderstorm with drizzle  \
# date_time
# 2012-10-02 09:00:00                                   False
# 2012-10-02 10:00:00                                   False
# 2012-10-02 11:00:00                                   False
# 2012-10-02 12:00:00                                   False
# 2012-10-02 13:00:00                                   False
# ...                                                     ...
# 2014-03-31 00:00:00                                   False
# 2014-03-31 01:00:00                                   False
# 2014-03-31 02:00:00                                   False
# 2014-03-31 03:00:00                                   False
# 2014-03-31 04:00:00                                   False
#
#                      weather_desc_thunderstorm with heavy rain  \
# date_time
# 2012-10-02 09:00:00                                      False
# 2012-10-02 10:00:00                                      False
# 2012-10-02 11:00:00                                      False
# 2012-10-02 12:00:00                                      False
# 2012-10-02 13:00:00                                      False
# ...                                                        ...
# 2014-03-31 00:00:00                                      False
# 2014-03-31 01:00:00                                      False
# 2014-03-31 02:00:00                                      False
# 2014-03-31 03:00:00                                      False
# 2014-03-31 04:00:00                                      False
#
#                      weather_desc_thunderstorm with light drizzle  \
# date_time
# 2012-10-02 09:00:00                                         False
# 2012-10-02 10:00:00                                         False
# 2012-10-02 11:00:00                                         False
# 2012-10-02 12:00:00                                         False
# 2012-10-02 13:00:00                                         False
# ...                                                           ...
# 2014-03-31 00:00:00                                         False
# 2014-03-31 01:00:00                                         False
# 2014-03-31 02:00:00                                         False
# 2014-03-31 03:00:00                                         False
# 2014-03-31 04:00:00                                         False
#
#                      weather_desc_thunderstorm with light rain  \
# date_time
# 2012-10-02 09:00:00                                      False
# 2012-10-02 10:00:00                                      False
# 2012-10-02 11:00:00                                      False
# 2012-10-02 12:00:00                                      False
# 2012-10-02 13:00:00                                      False
# ...                                                        ...
# 2014-03-31 00:00:00                                      False
# 2014-03-31 01:00:00                                      False
# 2014-03-31 02:00:00                                      False
# 2014-03-31 03:00:00                                      False
# 2014-03-31 04:00:00                                      False
#
#                      weather_desc_thunderstorm with rain  \
# date_time
# 2012-10-02 09:00:00                                False
# 2012-10-02 10:00:00                                False
# 2012-10-02 11:00:00                                False
# 2012-10-02 12:00:00                                False
# 2012-10-02 13:00:00                                False
# ...                                                  ...
# 2014-03-31 00:00:00                                False
# 2014-03-31 01:00:00                                False
# 2014-03-31 02:00:00                                False
# 2014-03-31 03:00:00                                False
# 2014-03-31 04:00:00                                False
#
#                      weather_desc_very heavy rain
# date_time
# 2012-10-02 09:00:00                         False
# 2012-10-02 10:00:00                         False
# 2012-10-02 11:00:00                         False
# 2012-10-02 12:00:00                         False
# 2012-10-02 13:00:00                         False
# ...                                           ...
# 2014-03-31 00:00:00                         False
# 2014-03-31 01:00:00                         False
# 2014-03-31 02:00:00                         False
# 2014-03-31 03:00:00                         False
# 2014-03-31 04:00:00                         False
#
# [13313 rows x 57 columns]

# %%
# Convert the data to NumPy arrays
print(endog.dtype)
print(exog.dtype)
if endog.dtype != np.float64:
    endog = endog.astype(np.float64)
if exog.dtype != np.float64:
    exog = exog.astype(np.float64)
# Out:
# float64
# object

# %% [markdown]
# ## Train the Model (Slow Cell)

# %%
# Fit the model
mod = sm.tsa.statespace.SARIMAX(endog, exog=exog, order=(1,0,1))
fit_res = mod.fit(disp=False)
print(fit_res.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                13313
# Model:               SARIMAX(1, 0, 1)   Log Likelihood             -108201.617
# Date:                Mon, 15 Apr 2024   AIC                         216523.233
# Time:                        09:20:26   BIC                         216973.023
# Sample:                             0   HQIC                        216673.344
#                               - 13313
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2403.1344    120.017    -20.023      0.000   -2638.364   -2167.905
# x1            -0.0979      0.053     -1.836      0.066      -0.202       0.007
# x2             0.8880      0.883      1.006      0.315      -0.843       2.619
# x3           -56.7940      4.520    -12.566      0.000     -65.652     -47.936
# x4             0.1666      0.089      1.880      0.060      -0.007       0.340
# x5             0.1491      0.920      0.162      0.871      -1.654       1.952
# x6             0.1491      0.914      0.163      0.871      -1.643       1.941
# x7            21.0603      0.302     69.678      0.000      20.468      21.653
# x8            45.0008      5.426      8.294      0.000      34.366      55.635
# x9          1.813e-12   3.97e-06   4.57e-07      1.000   -7.78e-06    7.78e-06
# x10            1.6597      0.446      3.721      0.000       0.785       2.534
# x11         3.469e-13        nan        nan        nan         nan         nan
# x12          -79.5656     23.787     -3.345      0.001    -126.186     -32.945
# x13        -8.306e-13   1.61e-06  -5.15e-07      1.000   -3.16e-06    3.16e-06
# x14          -95.4618     21.799     -4.379      0.000    -138.187     -52.737
# x15         -235.5608     40.113     -5.872      0.000    -314.181    -156.941
# x16         -162.8140     23.140     -7.036      0.000    -208.168    -117.460
# x17           75.2651     17.687      4.255      0.000      40.600     109.930
# x18         -226.3192     13.834    -16.359      0.000    -253.434    -199.204
# x19          -44.6884     68.477     -0.653      0.514    -178.901      89.524
# x20          435.6000     40.826     10.670      0.000     355.582     515.618
# x21        -1247.1188     57.672    -21.624      0.000   -1360.154   -1134.084
# x22         -822.4711     53.808    -15.285      0.000    -927.933    -717.009
# x23        -1247.1188     57.672    -21.624      0.000   -1360.154   -1134.084
# x24           39.4589     25.612      1.541      0.123     -10.740      89.658
# x25          -82.7302     19.130     -4.325      0.000    -120.224     -45.237
# x26         -402.3623     52.325     -7.690      0.000    -504.917    -299.807
# x27           76.7091     27.207      2.819      0.005      23.385     130.034
# x28         -162.8140     23.140     -7.036      0.000    -208.168    -117.460
# x29          314.1135    457.875      0.686      0.493    -583.305    1211.532
# x30           75.2651     17.687      4.255      0.000      40.600     109.930
# x31          441.7379     97.607      4.526      0.000     250.432     633.044
# x32         -471.5521     96.218     -4.901      0.000    -660.136    -282.968
# x33         -867.4898     45.367    -19.121      0.000    -956.408    -778.571
# x34         -274.9365     47.292     -5.814      0.000    -367.627    -182.246
# x35         1030.4733    137.550      7.492      0.000     760.881    1300.065
# x36         -223.2386     76.972     -2.900      0.004    -374.102     -72.375
# x37         1504.0845     96.931     15.517      0.000    1314.104    1694.065
# x38         -975.0403     58.023    -16.804      0.000   -1088.763    -861.318
# x39         -226.3192     13.833    -16.360      0.000    -253.432    -199.206
# x40         -495.5656     82.476     -6.009      0.000    -657.216    -333.915
# x41         -328.8263     21.379    -15.381      0.000    -370.728    -286.924
# x42         1490.6252    165.665      8.998      0.000    1165.928    1815.322
# x43         -315.0705     69.265     -4.549      0.000    -450.827    -179.314
# x44          839.6036    216.745      3.874      0.000     414.791    1264.416
# x45        -1164.8077     82.083    -14.191      0.000   -1325.688   -1003.928
# x46          239.3856     19.193     12.473      0.000     201.769     277.002
# x47         1850.4892    164.345     11.260      0.000    1528.379    2172.599
# x48         -119.0245     21.184     -5.618      0.000    -160.545     -77.504
# x49        -1076.4435     62.733    -17.159      0.000   -1199.398    -953.489
# x50        -1513.1244     92.988    -16.272      0.000   -1695.377   -1330.871
# x51         1516.4156    302.559      5.012      0.000     923.410    2109.421
# x52         -496.2614     93.357     -5.316      0.000    -679.237    -313.286
# x53        -1623.3108    173.292     -9.367      0.000   -1962.958   -1283.664
# x54          175.8525    137.714      1.277      0.202     -94.061     445.766
# x55         1758.2322    113.577     15.481      0.000    1535.626    1980.838
# x56        -1689.5442    156.548    -10.792      0.000   -1996.373   -1382.715
# ar.L1          0.8447      0.006    136.355      0.000       0.833       0.857
# ma.L1          0.3396      0.007     51.213      0.000       0.327       0.353
# sigma2      6.862e+05   5949.333    115.348      0.000    6.75e+05    6.98e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  39.90   Jarque-Bera (JB):             20984.27
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.08   Skew:                             1.03
# Prob(H) (two-sided):                  0.01   Kurtosis:                         8.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.93e+21. Standard errors may be unstable.

# %% [markdown]
# ## Read in Test Set

# %%
test_set = pd.read_csv("/content/Test.csv")
test_set.index = test_set.date_time
test_set = test_set.drop(['date_time'],axis=1)
test_set.head()
# Out:
#                     is_holiday  air_pollution_index  humidity  wind_speed  \
# date_time
# 2017-05-18 00:00:00        NaN                   73        63           1
# 2017-05-18 00:00:00        NaN                  251        63           1
# 2017-05-18 00:00:00        NaN                   75        56           1
# 2017-05-18 01:00:00        NaN                   98        56           1
# 2017-05-18 01:00:00        NaN                  283        56           1
#
#                      wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2017-05-18 00:00:00              27                    4          4
# 2017-05-18 00:00:00              27                    4          4
# 2017-05-18 00:00:00               0                    1          1
# 2017-05-18 01:00:00             351                    2          2
# 2017-05-18 01:00:00             351                    1          1
#
#                      temperature  rain_p_h  snow_p_h  clouds_all weather_type  \
# date_time
# 2017-05-18 00:00:00       285.15       0.0         0          90         Rain
# 2017-05-18 00:00:00       285.15       0.0         0          90         Mist
# 2017-05-18 00:00:00       285.15       0.0         0          90      Drizzle
# 2017-05-18 01:00:00       284.79       0.0         0          90         Rain
# 2017-05-18 01:00:00       284.79       0.0         0          90         Mist
#
#                          weather_description
# date_time
# 2017-05-18 00:00:00            moderate rain
# 2017-05-18 00:00:00                     mist
# 2017-05-18 00:00:00  light intensity drizzle
# 2017-05-18 01:00:00     heavy intensity rain
# 2017-05-18 01:00:00                     mist

# %%
test_set = pre_process(test_set)
# Out:
#   0%|          | 0/14454 [00:00<?, ?it/s]<ipython-input-6-5fe0e72183f9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.iloc[i]['holiday'] = 1
# 100%|██████████| 14454/14454 [00:03<00:00, 4386.95it/s]

# %%
test_set.head()
# Out:
#                      air_pollution_index  humidity  wind_speed  \
# date_time
# 2017-05-18 00:00:00                   73        63           1
# 2017-05-18 00:00:00                  251        63           1
# 2017-05-18 00:00:00                   75        56           1
# 2017-05-18 01:00:00                   98        56           1
# 2017-05-18 01:00:00                  283        56           1
#
#                      wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2017-05-18 00:00:00              27                    4          4
# 2017-05-18 00:00:00              27                    4          4
# 2017-05-18 00:00:00               0                    1          1
# 2017-05-18 01:00:00             351                    2          2
# 2017-05-18 01:00:00             351                    1          1
#
#                      temperature  rain_p_h  snow_p_h  clouds_all  ...  \
# date_time                                                         ...
# 2017-05-18 00:00:00       285.15       0.0         0          90  ...
# 2017-05-18 00:00:00       285.15       0.0         0          90  ...
# 2017-05-18 00:00:00       285.15       0.0         0          90  ...
# 2017-05-18 01:00:00       284.79       0.0         0          90  ...
# 2017-05-18 01:00:00       284.79       0.0         0          90  ...
#
#                      weather_desc_shower drizzle  weather_desc_sky is clear  \
# date_time
# 2017-05-18 00:00:00                        False                      False
# 2017-05-18 00:00:00                        False                      False
# 2017-05-18 00:00:00                        False                      False
# 2017-05-18 01:00:00                        False                      False
# 2017-05-18 01:00:00                        False                      False
#
#                      weather_desc_sleet  weather_desc_smoke  \
# date_time
# 2017-05-18 00:00:00               False               False
# 2017-05-18 00:00:00               False               False
# 2017-05-18 00:00:00               False               False
# 2017-05-18 01:00:00               False               False
# 2017-05-18 01:00:00               False               False
#
#                      weather_desc_snow  weather_desc_thunderstorm  \
# date_time
# 2017-05-18 00:00:00              False                      False
# 2017-05-18 00:00:00              False                      False
# 2017-05-18 00:00:00              False                      False
# 2017-05-18 01:00:00              False                      False
# 2017-05-18 01:00:00              False                      False
#
#                      weather_desc_thunderstorm with heavy rain  \
# date_time
# 2017-05-18 00:00:00                                      False
# 2017-05-18 00:00:00                                      False
# 2017-05-18 00:00:00                                      False
# 2017-05-18 01:00:00                                      False
# 2017-05-18 01:00:00                                      False
#
#                      weather_desc_thunderstorm with light drizzle  \
# date_time
# 2017-05-18 00:00:00                                         False
# 2017-05-18 00:00:00                                         False
# 2017-05-18 00:00:00                                         False
# 2017-05-18 01:00:00                                         False
# 2017-05-18 01:00:00                                         False
#
#                      weather_desc_thunderstorm with light rain  \
# date_time
# 2017-05-18 00:00:00                                      False
# 2017-05-18 00:00:00                                      False
# 2017-05-18 00:00:00                                      False
# 2017-05-18 01:00:00                                      False
# 2017-05-18 01:00:00                                      False
#
#                      weather_desc_thunderstorm with rain
# date_time
# 2017-05-18 00:00:00                                False
# 2017-05-18 00:00:00                                False
# 2017-05-18 00:00:00                                False
# 2017-05-18 01:00:00                                False
# 2017-05-18 01:00:00                                False
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Handling columns that aren't present in the test set, but are in the train set

# %%
for i in train.columns:
    if i not in test_set.columns:
        test_set[i] = 0
test_set.tail()
# Out:
#                      air_pollution_index  humidity  wind_speed  \
# date_time
# 2018-09-30 19:00:00                  176        21           4
# 2018-09-30 20:00:00                  214        95           8
# 2018-09-30 21:00:00                  173        63           4
# 2018-09-30 22:00:00                   21        57           8
# 2018-09-30 23:00:00                  116        70           8
#
#                      wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2018-09-30 19:00:00             345                    4          4
# 2018-09-30 20:00:00             280                    6          6
# 2018-09-30 21:00:00             238                    1          1
# 2018-09-30 22:00:00             268                    7          7
# 2018-09-30 23:00:00             328                    6          6
#
#                      temperature  rain_p_h  snow_p_h  clouds_all  ...  \
# date_time                                                         ...
# 2018-09-30 19:00:00       283.45       0.0         0          75  ...
# 2018-09-30 20:00:00       282.76       0.0         0          90  ...
# 2018-09-30 21:00:00       282.73       0.0         0          90  ...
# 2018-09-30 22:00:00       282.09       0.0         0          90  ...
# 2018-09-30 23:00:00       282.12       0.0         0          90  ...
#
#                      weather_desc_thunderstorm with rain  traffic_volume  \
# date_time
# 2018-09-30 19:00:00                                False               0
# 2018-09-30 20:00:00                                False               0
# 2018-09-30 21:00:00                                False               0
# 2018-09-30 22:00:00                                False               0
# 2018-09-30 23:00:00                                False               0
#
#                      weather_type_Clo  weather_type_Squall  \
# date_time
# 2018-09-30 19:00:00                 0                    0
# 2018-09-30 20:00:00                 0                    0
# 2018-09-30 21:00:00                 0                    0
# 2018-09-30 22:00:00                 0                    0
# 2018-09-30 23:00:00                 0                    0
#
#                      weather_desc_SQUALLS  weather_desc_freezing rain  \
# date_time
# 2018-09-30 19:00:00                     0                           0
# 2018-09-30 20:00:00                     0                           0
# 2018-09-30 21:00:00                     0                           0
# 2018-09-30 22:00:00                     0                           0
# 2018-09-30 23:00:00                     0                           0
#
#                      weather_desc_light rain and snow  \
# date_time
# 2018-09-30 19:00:00                                 0
# 2018-09-30 20:00:00                                 0
# 2018-09-30 21:00:00                                 0
# 2018-09-30 22:00:00                                 0
# 2018-09-30 23:00:00                                 0
#
#                      weather_desc_shower snow  \
# date_time
# 2018-09-30 19:00:00                         0
# 2018-09-30 20:00:00                         0
# 2018-09-30 21:00:00                         0
# 2018-09-30 22:00:00                         0
# 2018-09-30 23:00:00                         0
#
#                      weather_desc_thunderstorm with drizzle  \
# date_time
# 2018-09-30 19:00:00                                       0
# 2018-09-30 20:00:00                                       0
# 2018-09-30 21:00:00                                       0
# 2018-09-30 22:00:00                                       0
# 2018-09-30 23:00:00                                       0
#
#                      weather_desc_very heavy rain
# date_time
# 2018-09-30 19:00:00                             0
# 2018-09-30 20:00:00                             0
# 2018-09-30 21:00:00                             0
# 2018-09-30 22:00:00                             0
# 2018-09-30 23:00:00                             0
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Forecasting the traffic_volume for the given test set

# %%
# last_train = train.iloc[len(train)-1].name
first_predict = test_set.iloc[0].name
# print(last_train,first_predict)
# import datetime as dt

# start_dt = dt.datetime.strptime(last_train, '%Y-%m-%d %H:%M:%S')
# predict_dt = dt.datetime.strptime(first_predict, '%Y-%m-%d %H:%M:%S')
# diff = (predict_dt - start_dt)
# days, seconds = diff.days, diff.seconds
# hours = days * 24 + seconds // 3600
# print(hours)

exog1 = (sm.add_constant(test_set).loc[first_predict:])
exog1 = exog1.drop(['traffic_volume'],axis=1)

# print(pd.concat([exog,exog1]))
# predict = fit_res.predict(start=hours,end=hours,exog=exog1)
# print(predict)

print(exog1)

# Impute missing values with the mean
exog1 = exog1.fillna(exog1.mean())

# Convert data type to float
exog1 = exog1.astype(float)

# Reshape exog1 to match the model
exog1 = exog1.iloc[:, :-5]

print(exog1.shape)
forecast = fit_res.forecast(steps = len(test_set),exog = exog1)
print(forecast,len(forecast),len(test_set))
# Out:
#                      const  air_pollution_index  humidity  wind_speed  \
# date_time
# 2017-05-18 00:00:00    1.0                   73        63           1
# 2017-05-18 00:00:00    1.0                  251        63           1
# 2017-05-18 00:00:00    1.0                   75        56           1
# 2017-05-18 01:00:00    1.0                   98        56           1
# 2017-05-18 01:00:00    1.0                  283        56           1
# ...                    ...                  ...       ...         ...
# 2018-09-30 19:00:00    1.0                  176        21           4
# 2018-09-30 20:00:00    1.0                  214        95           8
# 2018-09-30 21:00:00    1.0                  173        63           4
# 2018-09-30 22:00:00    1.0                   21        57           8
# 2018-09-30 23:00:00    1.0                  116        70           8
#
#                      wind_direction  visibility_in_miles  dew_point  \
# date_time
# 2017-05-18 00:00:00              27                    4          4
# 2017-05-18 00:00:00              27                    4          4
# 2017-05-18 00:00:00               0                    1          1
# 2017-05-18 01:00:00             351                    2          2
# 2017-05-18 01:00:00             351                    1          1
# ...                             ...                  ...        ...
# 2018-09-30 19:00:00             345                    4          4
# 2018-09-30 20:00:00             280                    6          6
# 2018-09-30 21:00:00             238                    1          1
# 2018-09-30 22:00:00             268                    7          7
# 2018-09-30 23:00:00             328                    6          6
#
#                      temperature  rain_p_h  snow_p_h  ...  \
# date_time                                             ...
# 2017-05-18 00:00:00       285.15       0.0         0  ...
# 2017-05-18 00:00:00       285.15       0.0         0  ...
# 2017-05-18 00:00:00       285.15       0.0         0  ...
# 2017-05-18 01:00:00       284.79       0.0         0  ...
# 2017-05-18 01:00:00       284.79       0.0         0  ...
# ...                          ...       ...       ...  ...
# 2018-09-30 19:00:00       283.45       0.0         0  ...
# 2018-09-30 20:00:00       282.76       0.0         0  ...
# 2018-09-30 21:00:00       282.73       0.0         0  ...
# 2018-09-30 22:00:00       282.09       0.0         0  ...
# 2018-09-30 23:00:00       282.12       0.0         0  ...
#
#                      weather_desc_thunderstorm with light rain  \
# date_time
# 2017-05-18 00:00:00                                      False
# 2017-05-18 00:00:00                                      False
# 2017-05-18 00:00:00                                      False
# 2017-05-18 01:00:00                                      False
# 2017-05-18 01:00:00                                      False
# ...                                                        ...
# 2018-09-30 19:00:00                                      False
# 2018-09-30 20:00:00                                      False
# 2018-09-30 21:00:00                                      False
# 2018-09-30 22:00:00                                      False
# 2018-09-30 23:00:00                                      False
#
#                      weather_desc_thunderstorm with rain  weather_type_Clo  \
# date_time
# 2017-05-18 00:00:00                                False                 0
# 2017-05-18 00:00:00                                False                 0
# 2017-05-18 00:00:00                                False                 0
# 2017-05-18 01:00:00                                False                 0
# 2017-05-18 01:00:00                                False                 0
# ...                                                  ...               ...
# 2018-09-30 19:00:00                                False                 0
# 2018-09-30 20:00:00                                False                 0
# 2018-09-30 21:00:00                                False                 0
# 2018-09-30 22:00:00                                False                 0
# 2018-09-30 23:00:00                                False                 0
#
#                      weather_type_Squall  weather_desc_SQUALLS  \
# date_time
# 2017-05-18 00:00:00                    0                     0
# 2017-05-18 00:00:00                    0                     0
# 2017-05-18 00:00:00                    0                     0
# 2017-05-18 01:00:00                    0                     0
# 2017-05-18 01:00:00                    0                     0
# ...                                  ...                   ...
# 2018-09-30 19:00:00                    0                     0
# 2018-09-30 20:00:00                    0                     0
# 2018-09-30 21:00:00                    0                     0
# 2018-09-30 22:00:00                    0                     0
# 2018-09-30 23:00:00                    0                     0
#
#                      weather_desc_freezing rain  \
# date_time
# 2017-05-18 00:00:00                           0
# 2017-05-18 00:00:00                           0
# 2017-05-18 00:00:00                           0
# 2017-05-18 01:00:00                           0
# 2017-05-18 01:00:00                           0
# ...                                         ...
# 2018-09-30 19:00:00                           0
# 2018-09-30 20:00:00                           0
# 2018-09-30 21:00:00                           0
# 2018-09-30 22:00:00                           0
# 2018-09-30 23:00:00                           0
#
#                      weather_desc_light rain and snow  \
# date_time
# 2017-05-18 00:00:00                                 0
# 2017-05-18 00:00:00                                 0
# 2017-05-18 00:00:00                                 0
# 2017-05-18 01:00:00                                 0
# 2017-05-18 01:00:00                                 0
# ...                                               ...
# 2018-09-30 19:00:00                                 0
# 2018-09-30 20:00:00                                 0
# 2018-09-30 21:00:00                                 0
# 2018-09-30 22:00:00                                 0
# 2018-09-30 23:00:00                                 0
#
#                      weather_desc_shower snow  \
# date_time
# 2017-05-18 00:00:00                         0
# 2017-05-18 00:00:00                         0
# 2017-05-18 00:00:00                         0
# 2017-05-18 01:00:00                         0
# 2017-05-18 01:00:00                         0
# ...                                       ...
# 2018-09-30 19:00:00                         0
# 2018-09-30 20:00:00                         0
# 2018-09-30 21:00:00                         0
# 2018-09-30 22:00:00                         0
# 2018-09-30 23:00:00                         0
#
#                      weather_desc_thunderstorm with drizzle  \
# date_time
# 2017-05-18 00:00:00                                       0
# 2017-05-18 00:00:00                                       0
# 2017-05-18 00:00:00                                       0
# 2017-05-18 01:00:00                                       0
# 2017-05-18 01:00:00                                       0
# ...                                                     ...
# 2018-09-30 19:00:00                                       0
# 2018-09-30 20:00:00                                       0
# 2018-09-30 21:00:00                                       0
# 2018-09-30 22:00:00                                       0
# 2018-09-30 23:00:00                                       0
#
#                      weather_desc_very heavy rain
# date_time
# 2017-05-18 00:00:00                             0
# 2017-05-18 00:00:00                             0
# 2017-05-18 00:00:00                             0
# 2017-05-18 01:00:00                             0
# 2017-05-18 01:00:00                             0
# ...                                           ...
# 2018-09-30 19:00:00                             0
# 2018-09-30 20:00:00                             0
# 2018-09-30 21:00:00                             0
# 2018-09-30 22:00:00                             0
# 2018-09-30 23:00:00                             0
#
# [14454 rows x 62 columns]
# (14454, 57)
# [2916.44167429 1801.05229016 2577.81034146 ... 1809.71571158 2353.05224957
#  2365.62102701] 14454 14454

# %%
result_data = pd.DataFrame(index=test_set.index, columns=['date_time','traffic_volume'])
result_data.head()
# Out:
#                     date_time traffic_volume
# date_time
# 2017-05-18 00:00:00       NaN            NaN
# 2017-05-18 00:00:00       NaN            NaN
# 2017-05-18 00:00:00       NaN            NaN
# 2017-05-18 01:00:00       NaN            NaN
# 2017-05-18 01:00:00       NaN            NaN

# %%
chk = 0
for i in tqdm(forecast):
    result_data.iloc[chk]["date_time"] = test_set.iloc[chk].name
    result_data.iloc[chk]["traffic_volume"] = i
    chk+=1
result_data.head()
# Out:
# 100%|██████████| 14454/14454 [00:02<00:00, 4951.78it/s]
#                                date_time traffic_volume
# date_time
# 2017-05-18 00:00:00  2017-05-18 00:00:00    2916.441674
# 2017-05-18 00:00:00  2017-05-18 00:00:00     1801.05229
# 2017-05-18 00:00:00  2017-05-18 00:00:00    2577.810341
# 2017-05-18 01:00:00  2017-05-18 01:00:00    2602.146858
# 2017-05-18 01:00:00  2017-05-18 01:00:00    2545.516623

# %%
result_data.to_csv('results.csv', header=['date_time','traffic_volume'], index=False)
